# %%
import basedosdados as bd
import seaborn as sns
              
# Para carregar o dado direto no pandas
df = bd.read_table(dataset_id='br_isp_estatisticas_seguranca', 
table_id='taxa_evolucao_mensal_uf',
billing_project_id="apt-advantage-349005")
# Out:
# Downloading: 100%|████████████████████████████████████████████████████████████████| 222/222 [00:00<00:00, 436.44rows/s]

# %%
df.describe()
# Out:
#                ano         mes  hom_doloso  lesao_corp_morte  latrocinio  \
# count   222.000000  222.000000  222.000000        222.000000  222.000000
# mean   2011.756757    6.418919    2.686667          0.023153    0.089730
# std       5.356463    3.458899    0.691721          0.013619    0.036448
# min    2003.000000    1.000000    1.320000          0.000000    0.010000
# 25%    2007.000000    3.000000    2.130000          0.010000    0.060000
# 50%    2012.000000    6.000000    2.605000          0.020000    0.090000
# 75%    2016.000000    9.000000    3.280000          0.030000    0.110000
# max    2021.000000   12.000000    4.520000          0.070000    0.200000
#
#              cvli  hom_por_interv_policial  letalidade_violenta  tentat_hom  \
# count  222.000000               222.000000           222.000000  222.000000
# mean     2.799685                 0.522793             3.322297    2.470946
# std      0.716795                 0.229213             0.796281    0.477256
# ...

# %%
sns.displot(data=df, y="hom_doloso",x="mes", hue="ano",col="ano")
