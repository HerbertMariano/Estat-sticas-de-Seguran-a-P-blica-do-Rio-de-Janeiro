# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("crimes.csv")
df
# Out:
#      Unnamed: 0   ano  mes  mes_ano  hom_doloso  lesao_corp_morte  latrocinio  \
# 0             0  2003    1  2003m01        4.01              0.04        0.14
# 1             1  2003    2  2003m02        3.97              0.03        0.08
# 2             2  2003    3  2003m03        4.17              0.03        0.11
# 3             3  2003    4  2003m04        3.98              0.07        0.10
# 4             4  2003    5  2003m05        4.08              0.04        0.14
# ..          ...   ...  ...      ...         ...               ...         ...
# 217         217  2021    2  2021m02        1.41              0.02        0.07
# 218         218  2021    3  2021m03        1.80              0.04        0.05
# 219         219  2021    4  2021m04        1.73              0.02        0.04
# 220         220  2021    5  2021m05        1.52              0.01        0.03
# 221         221  2021    6  2021m06        1.32              0.04        0.01
#
# ...

# %%
sns.relplot(data=df,x="mes",y="hom_doloso",hue="ano",col="ano",kind="line", linewidth=4, zorder=5,col_wrap=3, height=2, aspect=1.5, legend=False)
